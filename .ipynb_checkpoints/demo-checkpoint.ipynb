# %%
# %pylab inline
from __future__ import division
import os
import numpy as np
import PIL.Image as pil
import tensorflow as tf
from SfMLearner import SfMLearner
from utils import normalize_depth_for_display
import cv2

img_height=128
img_width=416
ckpt_file_1 = './checkpoint_2/model.latest'
ckpt_file_2 = './models/depth_model/model-190532'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# fh = open('misc/sample.png', 'r')
# fh = open('./KITTI/SfMLearnerData/2011_09_26_drive_0001_sync_02/0000000018.jpg', 'r')
fh = open('/home/skotasai/SfMLearner/KITTI/2011_09_26/2011_09_26_drive_0093_sync/image_02/data/0000000100.png', 'r')
I = pil.open(fh)
I = I.resize((img_width, img_height), pil.ANTIALIAS)
I = np.array(I)


fh_r = open('/home/skotasai/SfMLearner/KITTI/2011_09_26/2011_09_26_drive_0093_sync/image_03/data/0000000100.png', 'r')
I_r = pil.open(fh_r)
I_r = I_r.resize((img_width, img_height), pil.ANTIALIAS)
I_r = np.array(I_r)

# plt.imshow(I)

# %%
sfm = SfMLearner()
sfm.setup_inference(img_height,
                    img_width,
                    mode='depth')
# Out:
# WARNING:tensorflow:From SfMLearner.py:271: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From nets.py:77: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /opt/conda/envs/py27/lib/python2.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From nets.py:16: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From nets.py:120: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.

# %%
saver_1 = tf.train.Saver([var for var in tf.model_variables()]) 
with tf.Session() as sess:
    saver_1.restore(sess, ckpt_file_1)
    pred_1 = sfm.inference(I[None,:,:,:], sess, mode='depth')

saver_2 = tf.train.Saver([var for var in tf.model_variables()]) 
with tf.Session() as sess:
    saver_2.restore(sess, ckpt_file_2)
    pred_2 = sfm.inference(I[None,:,:,:], sess, mode='depth')
# Out:
# INFO:tensorflow:Restoring parameters from ./checkpoint_2/model.latest
# INFO:tensorflow:Restoring parameters from ./models/depth_model/model-190532

# %%
# Il = cv2.cvtColor(I,cv2.COLOR_RGB2GRAY)
# Ir = cv2.cvtColor(I_r,cv2.COLOR_RGB2GRAY)

# Il = np.uint8(Il)
# Ir = np.uint8(Ir)
# stereo = cv2.StereoBM_create(numDisparities=128,blockSize=11)
# disparity = stereo.compute(Il,Ir)
# # local_max = disparity.max()
# # local_min = disparity.min()
# # print ("MAX " + str(local_max))
# # print ("MIN " + str(local_min))
# # disparity = (disparity-local_min)*(1.0/(local_max-local_min))
# disparity = np.array(disparity, dtype=np.float32) / 16.0

# %%
figure(figsize=(15,15))
subplot(3,1,1); title("Image"); imshow(I)
# subplot(4,1,2); title("Ground Truth"); imshow(disparity,cmap='gray')
subplot(3,1,2); title("Updated SfMLearner"); imshow(normalize_depth_for_display(pred_1['depth'][0,:,:,0]))
subplot(3,1,3); title("Pre-Trained SfMLearner"); imshow(normalize_depth_for_display(pred_2['depth'][0,:,:,0]))

# %%
# import cv2
# img = cv2.imread('KITTI/SfMLearnerData/2011_09_26_drive_0001_sync_02/0000000021.jpg')

# plt.imshow(img)

# %%
# %matplotlib notebook 
# subplot(1,2,1); title("Image"); imshow(I)
# subplot(1,2,2); title("Image 2"); imshow(I_r)

# %%
sfm = SfMLearner()
sfm.setup_inference(img_height,
                    img_width,
                    mode='pose')
saver_1 = tf.train.Saver([var for var in tf.model_variables()]) 
with tf.Session() as sess:
    saver_1.restore(sess, ckpt_file_1)
    pred_1 = sfm.inference(I[None,:,:,:], sess, mode='pose')

print(pred_1)
